# %%
import keras
from keras.layers import Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model
from keras.layers import Input
from keras.layers import BatchNormalization
from keras.layers import UpSampling2D
from keras.layers import Concatenate
from keras.layers import Lambda 
from keras.utils import to_categorical
import tensorflow as tf
from keras.layers import Add 

from keras.layers import Reshape

from keras import backend as K
from keras import regularizers, optimizers
# Out:
# Using TensorFlow backend.

# %%
import scipy.io as scio
import numpy as np    
import os
import matplotlib.pyplot as plt
import math
import re
from scipy.misc import imsave
from scipy import ndimage, misc
from numpy import unravel_index
from operator import sub
from tqdm import tqdm
import cv2

# %%
from keras.callbacks import ReduceLROnPlateau, CSVLogger,EarlyStopping,ModelCheckpoint

# %%
def atoi(text) : 
    return int(text) if text.isdigit() else text

# %%
def natural_keys(text) :
    return [atoi(c) for c in re.split('(\d+)', text)]

# %%
file_root = 'C:/Users/PashupatiNath/Desktop/AI_Ass2/melanoma'
melanoma_images = []
for img in tqdm(os.listdir(file_root)):
    path = os.path.join(file_root,img)
    img = cv2.imread(path)
    img = cv2.resize(img, (256,256))
    melanoma_images.append(img)
# Out:
# 100%|████████████████████████████████████████| 374/374 [02:26<00:00,  2.55it/s]

# %%
plt.imshow(melanoma_images[1])

# %%
file_root = 'C:/Users/PashupatiNath/Desktop/AI_Ass2/gt'
ground_melanoma_images = []
for img in tqdm(os.listdir(file_root)):
    path = os.path.join(file_root,img)
    img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (256,256))
    ground_melanoma_images.append(img)
# Out:
# 100%|██████████████████████████████████████| 2000/2000 [02:04<00:00, 16.09it/s]

# %%
plt.imshow(ground_melanoma_images[1])

# %%
plt.imshow(ground_melanoma_images[6], cmap = "gray")

# %%
np.unique(ground_melanoma_images[6])
# Out:
# array([  0,  44,  47,  56,  86,  92,  94,  96,  99, 100, 101, 102, 103,
#        104, 105, 106, 107, 108, 121, 122, 123, 124, 125, 127, 130, 137,
#        138, 148, 152, 156, 159, 162, 164, 166, 172, 174, 176, 177, 186,
#        190, 194, 196, 198, 200, 206, 207, 208, 210, 212, 213, 215, 216,
#        219, 220, 222, 223, 225, 226, 227, 228, 230, 231, 232, 233, 234,
#        236, 237, 255], dtype=uint8)

# %%
ground_melanoma_images[6].shape
# Out:
# (256, 256)

# %%
ret,thresh_img = cv2.threshold(ground_melanoma_images[6],127,255,cv2.THRESH_BINARY)

# %%
plt.imshow(thresh_img,cmap = "gray")

# %%
file_root = 'C:/Users/PashupatiNath/Desktop/AI_Ass2/gt'
ground_melanoma_images = []
for img in tqdm(os.listdir(file_root)):
    path = os.path.join(file_root,img)
    img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (256,256))
    ret,img = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
    ground_melanoma_images.append(img)
# Out:
# 100%|██████████████████████████████████████| 2000/2000 [01:00<00:00, 32.87it/s]

# %%
len(ground_melanoma_images)
# Out:
# 2000

# %%
plt.imshow(ground_melanoma_images[6])

# %%
image=ground_melanoma_images[0]

# %%
image.shape
# Out:
# (256, 256)

# %%
np.unique(image)
# Out:
# array([  0, 255], dtype=uint8)

# %%
gt = np.array(ground_melanoma_images)

# %%
gt.shape
# Out:
# (2000, 256, 256)

# %%
np.unique(gt)
# Out:
# array([  0, 255], dtype=uint8)

# %%
gt=gt/255

# %%
np.unique(gt)
# Out:
# array([0., 1.])

# %%
plt.imshow(gt[6],cmap = "gray")

# %%
plt.imshow(ground_melanoma_images[6], cmap = "gray")

# %%
file_root = 'C:/Users/PashupatiNath/Desktop/AI_Ass2/other'
other_images = []
for img in tqdm(os.listdir(file_root)):
    path = os.path.join(file_root,img)
    img = cv2.imread(path)
    img = cv2.resize(img, (256,256))
    other_images.append(img)
# Out:
# 100%|██████████████████████████████████████| 1626/1626 [06:38<00:00,  4.08it/s]

# %%
gt.shape
# Out:
# (2000, 256, 256)

# %%
total_image=[]
for i in tqdm(melanoma_images):
    total_image.append(i)
# Out:
# 100%|████████████████████████████████████████████████| 374/374 [00:00<?, ?it/s]

# %%
for i in tqdm(other_images):
    total_image.append(i)
# Out:
# 100%|██████████████████████████████████| 1626/1626 [00:00<00:00, 811800.77it/s]

# %%
len(total_image)
# Out:
# 2000

# %%
total_images = np.array(total_image)

# %%
total_images.shape
# Out:
# (2000, 256, 256, 3)

# %%
plt.imshow(total_images[10],cmap='gray')

# %%
plt.imshow(gt[10])

# %%
total_images.shape
# Out:
# (2000, 256, 256, 3)

# %%
gt.shape
# Out:
# (2000, 256, 256)

# %%
np.save('C:/Users/PashupatiNath/Desktop/AI_Ass2/gt',gt)

# %%
np.save('C:/Users/PashupatiNath/Desktop/AI_Ass2/total_images',total_images)
